# %% [markdown]
# # Files exceptional handling logging and memory *management*
#
# 1. What is the difference between interpreted and compiled languages?
#   - The choice between interpreted and compiled languages depends on factors like performance needs, development speed, and the target environment.
# 2. What is exception handling in Python?
#   - Exception handling in Python is a mechanism that allows you to gracefully handle errors that occur during the execution of a program. It ensures that the program can respond to unexpected conditions or errors without crashing abruptly.
# 3. What is the purpose of the finally block in exception handling?
#   - The purpose of the finally block in exception handling is to ensure that specific cleanup actions or code are executed regardless of whether an exception occurred or not. The finally block is always executed after the try and except blocks, making it ideal for tasks like releasing resources, closing files, or resetting states.
# 4. What is logging in Python?
#   - Logging in Python is a way to track and record events or messages that happen during the execution of a program. It provides a robust mechanism for debugging, monitoring, and keeping track of the state and behavior of applications.
# 5. What is the significance of the __del__ method in Python?
#   - The __del__ method in Python is a special method, also known as the destructor, which is called when an object is about to be destroyed.
# 6. What is the difference between import and from ... import in Python?
#   - In Python, the import and from ... import statements are both used to include and use modules and their components in your program, but they serve slightly different purposes and provide different levels of access.
# 7. How can you handle multiple exceptions in Python?
#   - In Python, you can handle multiple exceptions in various ways using try and except blocks.
# 8. What is the purpose of the with statement when handling files in Python?
#   - The with statement in Python simplifies file handling by providing a context manager for managing resources like file objects. Its primary purpose is to ensure that resources, such as files, are properly managed, particularly that they are automatically closed when their usage is complete, even if an error occurs.
# 9. What is the difference between multithreading and multiprocessing?
#   - Use multithreading for tasks that spend most of their time waiting (e.g., web scraping, file I/O).
#   - Use multiprocessing for tasks that require heavy computation or can be distributed across multiple cores.
# 10. What are the advantages of using logging in a program?
#    - Using logging in a program provides several advantages, especially for monitoring, debugging, and maintaining applications.
# 11. What is memory management in Python?
#   - Memory management in Python refers to the process of efficiently handling memory allocation and deallocation for objects and data structures during the execution of a Python program.
# 12. What are the basic steps involved in exception handling in Python?
#    - Exception handling in Python is a structured way of handling runtime errors so that the program can continue executing even when unexpected situations arise.
# 13. Why is memory management important in Python?
#    - Memory management in Python is important for several reasons, as it directly impacts the performance, stability, and efficiency of your program. Efficient memory management helps prevent issues like memory leaks, unnecessary overhead, and slowdowns, which could affect both small applications and large-scale systems.
# 14. What is the role of try and except in exception handling?
#    - In Python, the try and except blocks play a central role in exception handling. They are used to handle errors or exceptions that might arise during the execution of a program, allowing the program to continue running or handle the error gracefully instead of crashing.
# 15. How does Python's garbage collection system work?
#    - Python's garbage collection system is designed to automatically manage memory by reclaiming memory from objects that are no longer in use or reachable by the program.
# 16. What is the purpose of the else block in exception handling?
#    - The else block in exception handling in Python is an optional part of the try-except structure, and it serves a specific purpose: it allows you to define a block of code that will only execute if no exceptions were raised in the associated try block.
# 17. What are the common logging levels in Python?
#    - In Python, the logging module provides several predefined logging levels to indicate the severity or importance of log messages. Each level represents a different level of severity, ranging from detailed debugging information to critical errors.
# 18. What is the difference between os.fork() and multiprocessing in Python?
#   - In Python, both os.fork() and multiprocessing allow for concurrent execution of processes, but they operate in very different ways and are suited for different types of tasks.
# 19. What is the importance of closing a file in Python?
#    - Closing a file in Python is important for several reasons, primarily related to resource management, data integrity, and system performance.
# 20. What is the difference between file.read() and file.readline() in Python?
#   - In Python, file.read() and file.readline() are both methods used to read the contents of a file, but they behave differently and are used in different scenarios.
# 21. What is the logging module in Python used for?
#   - The logging module in Python is used for tracking and recording events or messages that occur during the execution of a program.
# 22. What is the os module in Python used for in file handling?
#   - The os module in Python provides a way to interact with the operating system, allowing you to perform various file handling tasks, manage directories, and manipulate file paths.
# 23. What are the challenges associated with memory management in Python?
#   - Memory management in Python is an essential aspect of programming, but it comes with its own set of challenges. Understanding these challenges helps developers write more efficient code and optimize resource usage, especially for large-scale applications.
# 24. How do you raise an exception manually in Python?
#   - In Python, you can manually raise an exception using the raise statement. This allows you to trigger an exception in your code intentionally, either with a custom message or a specific exception type.
# 25. Why is it important to use multithreading in certain applications?
#   - Using multithreading in certain applications is important because it offers several benefits, particularly in scenarios where tasks are I/O-bound, require concurrency, or need to make optimal use of system resources.

# %%
# 1.How can you open a file for writing in Python and write a string to it?
with open("example.txt", "w") as file:
  file.write("Hello, this is a string written to the file.")

# %%
#2. Write a Python program to read the contents of a file and print each line?
with open("example.txt", "r") as file:
  data = file.read()
  print(data)
# Out:
# Hello, this is a string written to the file.

# %%
#3. How would you handle a case where the file doesn't exist while trying to open it for reading?
try:
  with open("non_existent_file.txt", "r") as file:
    data = file.read()
    print(data)
except FileNotFoundError as e:
  print("The file doesn't exist.",e)
# Out:
# The file doesn't exist. [Errno 2] No such file or directory: 'non_existent_file.txt'

# %%
#4. Write a Python script that reads from one file and writes its content to another file?
source_file = "source.txt"
destination_file = "destination.txt"

try:

    with open(source_file, "r") as source:
      content = source.read()

    # Open the destination file for writing
    with open(destination_file, "w") as destination:
      destination.write(content)

    print(f"Contents of '{source_file}' have been successfully written to '{destination_file}'.")
except FileNotFoundError:
    print(f"Error: The file '{source_file}' does not exist.")
# Out:
# Error: The file 'source.txt' does not exist.

# %%
#5. How would you catch and handle division by zero error in Python?
try:
  10/0
except ZeroDivisionError as e:
  print("Error: Division by zero is not allowed.",e)
# Out:
# Error: Division by zero is not allowed. division by zero

# %%
#6. Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging
logging.basicConfig( filename="error_log.txt", level=logging.ERROR, format="%(asctime)s - %(levelname)s - %(message)s")

def divide_numbers(a, b):
    try:

        result = a / b
        print(f"The result is: {result}")
    except ZeroDivisionError:
        logging.error("Division by zero error occurred.")
        print("Error: Division by zero is not allowed.")

# %%
divide_numbers(10,0)
# Out:
# ERROR:root:Division by zero error occurred.
# Error: Division by zero is not allowed.

# %%
#7.How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

logging.basicConfig( filename="app.log", level=logging.DEBUG, format="%(asctime)s - %(levelname)s - %(message)s")
logging.debug("This is a debug message.")
logging.info("This is an info message.")
logging.warning("This is a warning message.")
logging.error("This is an error message.")
logging.critical("This is a critical message.")
# Out:
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.
# CRITICAL:root:This is a critical message.

# %%
#8. Write a program to handle a file opening error using exception handling?
try:
  with open("file.txt", "r") as file:
    data = file.read()
    print(data)
except FileNotFoundError as e:
  print("The file doesn't exist.",e)
# Out:
# The file doesn't exist. [Errno 2] No such file or directory: 'file.txt'

# %%
#9. How can you read a file line by line and store its content in a list in Python?
with open("example.txt", 'r') as file:
    data = [line.strip() for data in file.readlines()]

print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e33abc236335> in <cell line: 2>()
#       1 #9. How can you read a file line by line and store its content in a list in Python?
# ----> 2 with open("example.txt", 'r') as file:
#       3     data = [line.strip() for data in file.readlines()]
#       4
#       5 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'

# %%
#10. How can you append data to an existing file in Python?
data_to_append = "This is a new line of text."
with open("example.txt", 'w') as file:
    file.write(data_to_append + '\n')

# %%
#11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist
my_dict = {"name": "Alice","age": 30,"city": "New York"}
key_to_access = "country"

try:
    value = my_dict[key_to_access]
    print(f"The value for '{key_to_access}' is: {value}")
except KeyError:
    print(f"Error: The key '{key_to_access}' does not exist in the dictionary.")
# Out:
# Error: The key 'country' does not exist in the dictionary.

# %%
#12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions
try:
  10/0
except ZeroDivisionError as e:
  print("Error: Division by zero is not allowed.",e)
except Exception as e:
  print("An unexpected error occurred.",e)
# Out:
# Error: Division by zero is not allowed. division by zero

# %%
#13. How would you check if a file exists before attempting to read it in Python?
import os

file_name = "example.txt"

if os.path.exists(file_name):
    with open(file_name, "r") as file:
        data = file.read()
        print(data)
else:
    print(f"The file '{file_name}' does not exist.")
# Out:
# The file 'example.txt' does not exist.

# %%
#14. Write a program that uses the logging module to log both informational and error messages?
import logging
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler("app.log"),
        logging.StreamHandler()
    ]
)

def divide_numbers(numerator, denominator):
    try:
        logging.info("Attempting to divide %d by %d", numerator, denominator)
        result = numerator / denominator
        logging.info("Division successful: %d / %d = %f", numerator, denominator, result)
        return result
    except ZeroDivisionError as e:
        logging.error("Error occurred: Cannot divide by zero. %s", e)
        return None
    except Exception as e:
        logging.error("An unexpected error occurred: %s", e)
        return None

if __name__ == "__main__":
    logging.info("Program started.")
    divide_numbers(10, 2)
    divide_numbers(10, 0)

    logging.info("Program completed.")
# Out:
# ERROR:root:Error occurred: Cannot divide by zero. division by zero

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is emptyF
file_name = "example.txt"
def print_file_content(file_name):
    try:
        with open(file_name, "r") as file:
            content = file.read()
            if not content:
                print(f"The file '{file_name}' is empty.")
            else:
                print("File content:")
                print(content)
    except FileNotFoundError:
        print(f"Error: The file '{file_name}' does not exist.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
print_file_content(file_name)
# Out:
# Error: The file 'example.txt' does not exist.

# %%
#16. Demonstrate how to use memory profiling to check the memory usage of a small program?


from memory_profiler import profile
import time

@profile
def memory_intensive_function():
    print("Starting the memory-intensive function.")

    # Create a large list
    large_list = [i for i in range(10**6)]

    # Simulate some processing
    time.sleep(2)

    # Free up memory
    del large_list
    print("Completed the memory-intensive function.")

if __name__ == "__main__":
    memory_intensive_function()
# Out:
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.10/dist-packages/memory_profiler.py", line 847, in enable
#     sys.settrace(self.trace_memory_usage)
# ERROR: Could not find file <ipython-input-11-6b5778db7f27>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# Starting the memory-intensive function.
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# ...

# %%
pip install memory-profiler

# %%
#17. Write a Python program to create and write a list of numbers to a file, one number per line
numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(str(number) + "\n")

# %%
# 18. How would you implement a basic logging setup that logs to a file with
import logging
from logging.handlers import RotatingFileHandler
def setup_logging():
    logger = logging.getLogger("MyLogger")
    logger.setLevel(logging.DEBUG)
    handler = RotatingFileHandler(
        "app.log",
        maxBytes=1 * 1024 * 1024,
        backupCount=5,
    )
    formatter = logging.Formatter(
        "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
    )
    handler.setFormatter(formatter)


    logger.addHandler(handler)

    return logger

if __name__ == "__main__":
    logger = setup_logging()


    for i in range(10000):
        logger.debug(f"This is debug message number {i}")
        logger.info(f"This is info message number {i}")
        logger.error(f"This is error message number {i}")
# Out:
# ERROR:MyLogger:This is error message number 9619
# DEBUG:MyLogger:This is debug message number 9620
# INFO:MyLogger:This is info message number 9620
# ERROR:MyLogger:This is error message number 9620
# DEBUG:MyLogger:This is debug message number 9621
# INFO:MyLogger:This is info message number 9621
# ERROR:MyLogger:This is error message number 9621
# DEBUG:MyLogger:This is debug message number 9622
# INFO:MyLogger:This is info message number 9622
# ERROR:MyLogger:This is error message number 9622
# DEBUG:MyLogger:This is debug message number 9623
# INFO:MyLogger:This is info message number 9623
# ERROR:MyLogger:This is error message number 9623
# DEBUG:MyLogger:This is debug message number 9624
# INFO:MyLogger:This is info message number 9624
# ERROR:MyLogger:This is error message number 9624
# DEBUG:MyLogger:This is debug message number 9625
# INFO:MyLogger:This is info message number 9625
# ERROR:MyLogger:This is error message number 9625
# ...

# %%
#19. Write a program that handles both IndexError and KeyError using a try-except block
def handle_exceptions():
    try:
        print("Choose an operation:")
        print("1. Access an element from a list by index")
        print("2. Access a value from a dictionary by key")

        choice = int(input("Enter your choice (1 or 2): "))

        if choice == 1:
            # Handling IndexError
            sample_list = [10, 20, 30]
            print(f"List: {sample_list}")
            index = int(input(f"Enter an index (0 to {len(sample_list)-1}): "))
            print(f"Element at index {index}: {sample_list[index]}")

        elif choice == 2:
            # Handling KeyError
            sample_dict = {"a": 100, "b": 200, "c": 300}
            print(f"Dictionary: {sample_dict}")
            key = input("Enter a key to access (e.g., 'a', 'b', 'c'): ")
            print(f"Value for key '{key}': {sample_dict[key]}")

        else:
            print("Invalid choice!")

    except IndexError as e:
        print(f"Error: Index out of range. {e}")

    except KeyError as e:
        print(f"Error: Key not found. {e}")

    except ValueError as e:
        print(f"Error: Invalid input. {e}")

    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    handle_exceptions()
# Out:
# Choose an operation:
# 1. Access an element from a list by index
# 2. Access a value from a dictionary by key
# Enter your choice (1 or 2): 1
# List: [10, 20, 30]
# Enter an index (0 to 2): 2
# Element at index 2: 30

# %%
#20 .How would you open a file and read its contents using a context manager in Python
with open("example.txt", "r") as file:
  data = file.read()
  print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-67a050223cc7> in <cell line: 2>()
#       1 #20 .How would you open a file and read its contents using a context manager in Python
# ----> 2 with open("example.txt", "r") as file:
#       3   data = file.read()
#       4   print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'

# %%
#21 .Write a Python program that reads a file and prints the number of occurrences of a specific word.

# %%
#22 .How can you check if a file is empty before attempting to read its contents
def is_file_empty(file_path):
    try:
      with open(file_path, "r") as file:
        data = file.read()
        print(data)
    except FileNotFoundError:
      print(f"The file '{file_path}' does not exist.")
    except Exception as e:
      print(f"An error occurred: {e}")

# %%
is_file_empty("example.txt")
# Out:
# The file 'example.txt' does not exist.

# %%
#23. Write a Python program that writes to a log file when an error occurs during file handling
import logging
logging.basicConfig(
    filename="file_errors.log",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def process_file(file_name):
    try:
        with open(file_name, "r") as file:
            content = file.read()
            print("File content:")
            print(content)
    except FileNotFoundError:
        error_message = f"FileNotFoundError: The file '{file_name}' does not exist."
        print(error_message)
        logging.error(error_message)
    except PermissionError:
        error_message = f"PermissionError: You do not have permission to access the file '{file_name}'."
        print(error_message)
        logging.error(error_message)
    except Exception as e:
        error_message = f"An unexpected error occurred: {e}"
        print(error_message)
        logging.error(error_message)

if __name__ == "__main__":
    file_name = input("Enter the file name: ")
    process_file(file_name)
# Out:
# Enter the file name: rohit.txt
# ERROR:root:FileNotFoundError: The file 'rohit.txt' does not exist.
# FileNotFoundError: The file 'rohit.txt' does not exist.
